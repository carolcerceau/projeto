# %% [markdown]
# <a href="https://colab.research.google.com/github/carolcerceau/projeto/blob/main/Projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lendo dados de um arquivo CSV
import pandas as pd
notas=pd.read_csv('Notas.csv', sep=';')
notas
# Out:
#        Aluno  D1    D2    D3
# 0      Maria  13  20.0  14.0
# 1       João  16  17.0  20.0
# 2       José  20  16.0  19.0
# 3  Alexandre  18  16.0   NaN
# 4      Paulo  19   9.0   7.0
# 5     Carlos   9  10.0  11.0
# 6      Pedro  11   NaN  18.0
# 7      Joana  19  20.0   3.0
# 8      Carla  17   NaN  17.0
# 9      Joana  19  20.0   3.0

# %%
#imprimindo a quantidade de linhas e colunas
notas.shape
# Out:
# (10, 4)

# %%
#exibindo as colunas
notas.columns
# Out:
# Index(['Aluno', 'D1', 'D2', 'D3'], dtype='object')

# %%
#resumo estatístico de todos os campos numéricos
notas.describe()
# Out:
#               D1         D2         D3
# count  10.000000   8.000000   9.000000
# mean   16.100000  16.000000  12.444444
# std     3.813718   4.375255   6.747427
# min     9.000000   9.000000   3.000000
# 25%    13.750000  14.500000   7.000000
# 50%    17.500000  16.500000  14.000000
# 75%    19.000000  20.000000  18.000000
# max    20.000000  20.000000  20.000000
